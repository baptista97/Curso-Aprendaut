# %%
import pandas as pd
from sklearn import preprocessing

# %%
df = pd.read_csv('data.csv', delimiter = ';', decimal= '.')

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Marital status, Application mode, Application order, Course, Daytime/evening attendance	, Previous qualification, Previous qualification (grade), Nacionality, Mother's qualification, Father's qualification, Mother's occupation, Father's occupation, Admission grade, Displaced, Educational special needs, Debtor, Tuition fees up to date, Gender, Scholarship holder, Age at enrollment, International, Curricular units 1st sem (credited), Curricular units 1st sem (enrolled), Curricular units 1st sem (evaluations), Curricular units 1st sem (approved), Curricular units 1st sem (grade), Curricular units 1st sem (without evaluations), Curricular units 2nd sem (credited), Curricular units 2nd sem (enrolled), Curricular units 2nd sem (evaluations), Curricular units 2nd sem (approved), Curricular units 2nd sem (grade), Curricular units 2nd sem (without evaluations), Unemployment rate, Inflation rate, GDP, Target]
# Index: []
#
# [0 rows x 37 columns]

# %%
df['Target'] = df['Target'].replace(['Enrolled'], 'Graduate')

# %%
nun = df.loc[:,'Target'].nunique()
un = df.loc[:,'Target'].unique()
print(nun)
print(un)
# Out:
# 2
# ['Dropout' 'Graduate']

# %%
enc = preprocessing.OrdinalEncoder()
enc.fit(df[['Target']])
for i, cat in enumerate(enc.categories_[0]): print(f'{cat} -> {i}')

df['output']  = enc.transform(df[['Target']])
df = df.astype({'output':'int64'})

df.head(10)
# Out:
# Dropout -> 0
# Graduate -> 1
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
# 5               2                39                  1    9991
# 6               1                 1                  1    9500
# 7               1                18                  4    9254
# 8               1                 1                  3    9238
# 9               1                 1                  1    9238
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# ...

# %%
df.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance\t                        int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# ...

# %%
df.shape #Nº de filas y Nº de columnas
# Out:
# (4424, 38)

# %%
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %% [markdown]
# Preprocessing continuous attributes

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.compose import ColumnTransformer

# %%
discr = KBinsDiscretizer()
c_data = df.select_dtypes(include=['float64'])
c_data.columns 
##Prev qual, Adm grade 0-200
##Unemployment, Inflation rate 0-100 %
##GDP: producto bruto interno
##Curricular Grade: 0-20
# Out:
# Index(['Previous qualification (grade)', 'Admission grade',
#        'Curricular units 1st sem (grade)', 'Curricular units 2nd sem (grade)',
#        'Unemployment rate', 'Inflation rate', 'GDP'],
#       dtype='object')

# %%
#Valor max y min de GDP
maxGDP = c_data['GDP'].max()
minGDP = c_data['GDP'].min()
results = [minGDP,maxGDP]
print(results)
# Out:
# [-4.06, 3.51]

# %%
print(c_data)
# Out:
#       Previous qualification (grade)  Admission grade  \
# 0                              122.0            127.3
# 1                              160.0            142.5
# 2                              122.0            124.8
# 3                              122.0            119.6
# 4                              100.0            141.5
# ...                              ...              ...
# 4419                           125.0            122.2
# 4420                           120.0            119.0
# 4421                           154.0            149.5
# 4422                           180.0            153.8
# 4423                           152.0            152.0
#
#       Curricular units 1st sem (grade)  Curricular units 2nd sem (grade)  \
# 0                             0.000000                          0.000000
# 1                            14.000000                         13.666667
# 2                             0.000000                          0.000000
# ...

# %%
est = KBinsDiscretizer(n_bins=3, encode='ordinal', strategy = 'uniform', subsample=None)

# %%
Xt = est.fit_transform(c_data)

# %%
est.bin_edges_[0]
# Out:
# array([ 95.        , 126.66666667, 158.33333333, 190.        ])

# %%
Xt_df = pd.DataFrame(Xt,
columns=['Previous qualification (grade)',
        'Admission grade',
        'Curricular units 1st sem (grade)',
        'Curricular units 2nd sem (grade)',
        'Unemployment rate',
        'Inflation rate',
        'GDP'])

# %%
Xt_df
# Out:
#       Previous qualification (grade)  Admission grade  \
# 0                                0.0              1.0
# 1                                2.0              1.0
# 2                                0.0              0.0
# 3                                0.0              0.0
# 4                                0.0              1.0
# ...                              ...              ...
# 4419                             0.0              0.0
# 4420                             0.0              0.0
# 4421                             1.0              1.0
# 4422                             2.0              1.0
# 4423                             1.0              1.0
#
#       Curricular units 1st sem (grade)  Curricular units 2nd sem (grade)  \
# 0                                  0.0                               0.0
# 1                                  2.0                               2.0
# 2                                  0.0                               0.0
# ...

# %%
Xt_df.to_csv('my_array.csv',header = False, index= False) #Chequear

# %%
df['GDP'] = Xt_df['GDP']
df['Inflation rate'] = Xt_df['Inflation rate']
df['Unemployment rate'] = Xt_df['Unemployment rate']
df['Curricular units 2nd sem (grade)'] = Xt_df['Curricular units 2nd sem (grade)']
df['Curricular units 1st sem (grade)'] = Xt_df['Curricular units 1st sem (grade)']
df['Admission grade'] = Xt_df['Admission grade']
df['Previous qualification (grade)'] = Xt_df['Previous qualification (grade)']

# %%
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %% [markdown]
# Train/Test split

# %%
import sklearn
import numpy as np
from sklearn.model_selection import train_test_split

# %%
y = df['output']
train, test = train_test_split(df, test_size=0.2 , stratify=y, random_state=42)
print(f'{train.shape[0]} samples for training, {test.shape[0]} samples for testing')
# Out:
# 3539 samples for training, 885 samples for testing

# %%
train
train.to_csv('train.csv',header = False, index= False) #Chequear

# %%
len(test[test.output == 1])
# Out:
# 601

# %%
len(test[test.output == 0])
# Out:
# 284

# %%
prop_test= (len(test[test.output == 1]))/(len(test[test.output == 0]) + len(test[test.output == 1])) * 100
prop_test
# Out:
# 67.909604519774

# %%
prop_train = (len(train[train.output == 1]))/(len(train[train.output == 0]) + len(train[train.output == 1])) * 100
prop_train
# Out:
# 67.87228030517095

# %% [markdown]
# Calculos de entropía y ganancia de información

# %%
class_list = train['output'].unique()
label = 'output'
c = 1
train_data = train

# %%
def calc_total_entropy(train_data, label, class_list):
    total_row = train_data.shape[0] #the total size of the dataset
    total_entr = 0
    
    for c in class_list: #for each class in the label
        total_class_count = train_data[train_data[label] == c].shape[0] #number of the class
        total_class_entr = - (total_class_count/total_row)*np.log2(total_class_count/total_row) #entropy of the class
        total_entr += total_class_entr #adding the class entropy to the total entropy of the dataset
    
    return total_entr

# %%
print(calc_total_entropy(train_data, label, class_list))
# Out:
# 0.9057649581840835

# %%
feature_value_data = train_data[train_data['Marital status'] == 1]
feature_value_data
# Out:
#       Marital status  Application mode  Application order  Course  \
# 3512               1                 1                  1     171
# 1030               1                 1                  2    9147
# 3833               1                 1                  1    9238
# 4006               1                44                  1    9003
# 1455               1                 1                  2    9147
# ...              ...               ...                ...     ...
# 1199               1                 7                  1    9085
# 1440               1                 1                  5    9670
# 4139               1                17                  1    9238
# 665                1                 1                  1    9085
# 3042               1                17                  4    9670
#
#       Daytime/evening attendance\t  Previous qualification  \
# 3512                             1                       1
# ...

# %%
def calc_entropy(feature_value_data, label, class_list):
    class_count = feature_value_data.shape[0]
    entropy = 0
    
    for c in class_list:
        label_class_count = feature_value_data[feature_value_data[label] == c].shape[0] #row count of class c 
        entropy_class = 0
        if label_class_count != 0:
            probability_class = label_class_count/class_count #probability of the class
            entropy_class = - probability_class * np.log2(probability_class)  #entropy
        entropy += entropy_class
    return entropy

# %%
print(calc_entropy(feature_value_data, label, class_list))
# Out:
# 0.8839630215188847

# %%
feature_name = 'GDP'

# %%
def calc_info_gain(feature_name, train_data, label, class_list):
    feature_value_list = train_data[feature_name].unique() #unqiue values of the feature
    total_row = train_data.shape[0]
    feature_info = 0.0
    
    for feature_value in feature_value_list:
        feature_value_data = train_data[train_data[feature_name] == feature_value] #filtering rows with that feature_value
        feature_value_count = feature_value_data.shape[0]
        feature_value_entropy = calc_entropy(feature_value_data, label, class_list) #calculcating entropy for the feature value
        feature_value_probability = feature_value_count/total_row
        feature_info += feature_value_probability * feature_value_entropy #calculating information of the feature value
        
    return calc_total_entropy(train_data, label, class_list) - feature_info #calculating information gain by subtracting

# %%
print(calc_info_gain(feature_name, train_data, label, class_list))
# Out:
# 0.0017276944875678213
